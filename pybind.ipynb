# %%
from tls_crypt import *

# %%
print pem2json('cert.pem')
# Out:
# [
# 	[
# 		[
# 			[
# 				"02:"
# 			],
# 			"00:d5:23:b2:35:6d:f1:dc:24:",
# 			[
# 				"2a:86:48:86:f7:0d:01:01:0b:",
# 				"null"
# 			],
# 			[
# 				[
# 					[
# 						"55:04:06:",
# 						"AU"
# 					]
# 				],
# 				[
# 					[
# 						"55:04:08:",
# 						"CA"
# 					]
# 				],
# 				[
# 					[
# 						"55:04:07:",
# 						"San francisco"
# 					]
# 				],
# 				[
# 					[
# 						"55:04:0a:",
# 						"Internet Widgits Pty Ltd"
# 					]
# 				],
# 				[
# 					[
# 						"55:04:03:",
# 						"psw"
# 					]
# 				],
# 				[
# 					[
# 						"2a:86:48:86:f7:0d:01:09:01:",
# 						"zezeon@msn.com"
# 					]
# 				]
# 			],
# 			[
# 				"180515055157Z",
# 				"210208055157Z"
# 			],
# 			[
# 				[
# 					[
# 						"55:04:06:",
# 						"AU"
# 					]
# 				],
# 				[
# 					[
# 						"55:04:08:",
# 						"CA"
# 					]
# 				],
# 				[
# 					[
# 						"55:04:07:",
# 						"San francisco"
# 					]
# 				],
# 				[
# 					[
# 						"55:04:0a:",
# 						"Internet Widgits Pty Ltd"
# ...
